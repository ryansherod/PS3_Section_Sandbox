# %% [markdown]
# # PS3 Week 4 Sandbox: Selection Bias and Fair Comparisons
#
# **Goal:** Practice using `table()`, `subset()`, `mean()`, and nested functions while learning why comparing people who choose a treatment can give a misleading estimate of its effect.
#
# This dataset is **synthetic**. It describes 120 fictional students and was designed only for practice.
#
# ### Today you will practice
# - creating subsets with one or more conditions
# - calculating and comparing group means
# - nesting one function inside another
# - recognizing self-selection bias
# - using baseline outcomes to check whether groups were comparable before treatment
# - explaining why random assignment creates a fairer comparison

# %% [markdown]
# ## 0. Setup
#
# Run the cell below once. It loads the checking tools and the practice dataset.

# %%
# Do not edit this cell. Just run it.
library(testthat)
library(ottr)

tutoring <- read.csv("PS3_Week4_Sandbox_Data.csv")
head(tutoring)

# %% [markdown]
# ## Meet the variables
#
# Each row represents one fictional student.
#
# | Variable | Meaning |
# |---|---|
# | `student_id` | Fictional student ID |
# | `offered` | Randomly offered access to free tutoring: 1 = yes, 0 = no |
# | `participated` | Participated in the tutoring program: 1 = yes, 0 = no |
# | `baseline_score` | Score on an earlier course exam before tutoring began |
# | `final_score` | Score on the final exam after tutoring began |
#
# Students who were not offered tutoring could not participate, so everyone with `offered == 0` also has `participated == 0`.

# %% [markdown]
# # Part 1 - Who is in the dataset?
#
# ### Question 1
#
# Create a two-way table called `group.counts` that counts students by whether they were offered tutoring and whether they participated.
#
# Put `offered` in the rows and `participated` in the columns.

# %%
group.counts <- # Your code here

group.counts

# %%
. = ottr::check("tests/q1.R")

# %% [markdown]
# ### Read the table
#
# 1. How many students were not offered tutoring?
# 2. Among students who were offered tutoring, how many participated and how many did not?
#
# >

# %% [markdown]
# # Part 2 - The tempting comparison
#
# Suppose we want to know whether tutoring improves final exam scores. One tempting approach is to compare students who chose to participate with students who were offered tutoring but chose not to participate.
#
# ### Question 2
#
# Create these two subsets:
#
# - `offered.did.not.participate`: students with `offered == 1` and `participated == 0`
# - `participated.in.tutoring`: students with `offered == 1` and `participated == 1`

# %%
offered.did.not.participate <- # Your code here

participated.in.tutoring <- # Your code here

# %%
. = ottr::check("tests/q2.R")

# %% [markdown]
# ### Question 3
#
# Calculate the mean final score for each group. Then calculate how many points lower participants scored by subtracting the participant mean from the nonparticipant mean.

# %%
mean.final.nonparticipants <- # Your code here

mean.final.participants <- # Your code here

final.score.difference <- # Your code here

# %%
. = ottr::check("tests/q3.R")

# %%
# Do not edit this summary. Just run it.
paste0(
  "Tutoring participants averaged ", round(mean.final.participants, 1),
  " points on the final exam. Eligible nonparticipants averaged ",
  round(mean.final.nonparticipants, 1), ". Participants therefore scored ",
  round(final.score.difference, 1), " points lower."
)

# %% [markdown]
# ### The suspicious headline
#
# An analyst looks at your results and writes:
#
# ## "Students who attended tutoring scored lower. Tutoring hurts academic performance."
#
# ### Question 4
#
# What does your comparison actually show? Does it establish that tutoring caused lower scores? Explain in 2-3 sentences.
#
# >

# %% [markdown]
# # Part 3 - Look backward before looking forward
#
# The dataset also records each student's `baseline_score`, measured before tutoring began.
#
# ### Question 5
#
# Calculate the mean baseline score for the same two groups. Then calculate how many points lower participants started by subtracting the participant mean from the nonparticipant mean.

# %%
mean.baseline.nonparticipants <- # Your code here

mean.baseline.participants <- # Your code here

baseline.score.difference <- # Your code here

# %%
. = ottr::check("tests/q5.R")

# %%
# Do not edit this summary. Just run it.
paste0(
  "Before tutoring began, eventual participants averaged ",
  round(mean.baseline.participants, 1),
  " points. Eligible nonparticipants averaged ",
  round(mean.baseline.nonparticipants, 1),
  ". Participants therefore started ", round(baseline.score.difference, 1),
  " points lower."
)

# %% [markdown]
# ### Question 6 - Diagnose the bias
#
# 1. Were participants and nonparticipants similar before tutoring began?
# 2. Tell a plausible story about why students with different baseline scores might make different choices about attending tutoring.
# 3. Why does that make the participant-versus-nonparticipant comparison a poor estimate of tutoring's causal effect?
#
# Write 2-4 sentences.
#
# >

# %% [markdown]
# # Part 4 - Use nested functions and the randomized groups
#
# Access to tutoring was assigned randomly. Students did not choose whether they were offered the program.
#
# A nested function places one function inside another. For the next two questions, use `subset()` inside `mean()` rather than creating additional datasets first.
#
# ### Question 7 - Check the starting point
#
# Calculate the mean baseline score among students offered tutoring and among students not offered tutoring. Then calculate the difference as offered minus not offered.

# %%
mean.baseline.offered <- # Your nested code here

mean.baseline.not.offered <- # Your nested code here

randomized.baseline.difference <- # Your code here

# %%
. = ottr::check("tests/q7.R")

# %%
# Do not edit this summary. Just run it.
paste0(
  "The offered group averaged ", round(mean.baseline.offered, 1),
  " points at baseline. The not-offered group averaged ",
  round(mean.baseline.not.offered, 1),
  ". The baseline difference was ",
  round(randomized.baseline.difference, 1), " points."
)

# %% [markdown]
# Random assignment does not guarantee perfectly identical groups in one sample. It makes pre-existing differences a matter of chance rather than student choice.

# %% [markdown]
# ### Question 8 - Compare the outcomes
#
# Use the same nested-function approach to calculate the mean final score among students offered tutoring and students not offered tutoring. Then calculate the difference as offered minus not offered.

# %%
mean.final.offered <- # Your nested code here

mean.final.not.offered <- # Your nested code here

randomized.final.difference <- # Your code here

# %%
. = ottr::check("tests/q8.R")

# %%
# Do not edit this summary. Just run it.
paste0(
  "The offered group averaged ", round(mean.final.offered, 1),
  " points on the final. The not-offered group averaged ",
  round(mean.final.not.offered, 1),
  ". The offered group therefore scored ",
  round(randomized.final.difference, 1), " points higher."
)

# %% [markdown]
# ### Question 9 - Interpret the two comparisons
#
# The same dataset produced:
#
# - a participant-versus-nonparticipant comparison, and
# - an offered-versus-not-offered comparison.
#
# Why do they tell different stories? Which comparison gives us better evidence about the causal effect of being offered tutoring, and why?
#
# Write 2-4 sentences.
#
# >

# %% [markdown]
# # Final challenge - Be the reviewer
#
# A campus newspaper reports:
#
# > "Tutoring participants averaged lower final scores than eligible nonparticipants, proving the program failed."
#
# Write a short correction that includes all three points:
#
# 1. the descriptive fact the participant comparison supports,
# 2. the evidence of self-selection in the baseline data, and
# 3. what the randomized comparison suggests instead.
#
# >

# %% [markdown]
# ## Done!
#
# Before you leave, make sure you can explain:
#
# - how to use multiple conditions inside `subset()`
# - how to place `subset()` inside `mean()`
# - why people who opt into a program may differ from people who opt out
# - how baseline data can reveal those pre-existing differences
# - why a randomized treatment offer is more useful for causal inference than participation choice
